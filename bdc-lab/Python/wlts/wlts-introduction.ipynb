# %% [markdown]
# <img src="https://raw.githubusercontent.com/brazil-data-cube/code-gallery/master/img/logo-bdc.png" align="right" width="64"/>
#
# # <span style="color:#336699">Introduction to the Web Land Trajectory Service (WLTS)</span>
# <hr style="border:2px solid #0077b9;">
#
# <div style=text-align: left;>
#     <a href="https://nbviewer.jupyter.org/github/brazil-data-cube/code-gallery/blob/master/jupyter/Python/wlts/wlts-introduction.ipynb"><img src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg" align="center"/></a>
# </div>
#
# <br/>
#
# <div style="text-align: center;font-size: 90%;">
#     Fabiana Zioti<sup><a href="https://orcid.org/0000-0002-7305-6043"><i class="fab fa-lg fa-orcid" style="color: #a6ce39"></i></a></sup>, Felipe Menino Carlos<sup><a href="https://orcid.org/0000-0002-3334-4315"><i class="fab fa-lg fa-orcid" style="color: #a6ce39"></i></a></sup>, Karine Reis Ferreira<sup><a href="https://orcid.org/0000-0003-2656-5504"><i class="fab fa-lg fa-orcid" style="color: #a6ce39"></i></a></sup>, Gilberto R. Queiroz<sup><a href="https://orcid.org/0000-0001-7534-0219"><i class="fab fa-lg fa-orcid" style="color: #a6ce39"></i></a></sup>
#     <br/><br/>
#     Earth Observation and Geoinformatics Division, National Institute for Space Research (INPE)
#     <br/>
#     Avenida dos Astronautas, 1758, Jardim da Granja, São José dos Campos, SP 12227-010, Brazil
#     <br/><br/>
#     Contact: <a href="mailto:brazildatacube@inpe.br">brazildatacube@inpe.br</a>
#     <br/><br/>
#     Last Update: November 07, 2023
# </div>
#
# <br/>
#
# <div style="text-align: justify;  margin-left: 25%; margin-right: 25%;">
# <b>Abstract.</b> This Jupyter Notebook gives an overview on how to use WLTS to discover and access land use and cover trajectories data from well-known projects, including PRODES, DETER, and TerraClass.
# </div>
#
# <br/>
#
# <div style="text-align: justify;  margin-left: 15%; margin-right: 15%;font-size: 75%; border-style: solid; border-color: #0077b9; border-width: 1px; padding: 5px;">
#     <b>This Jupyter Notebook is supplement to the <a href="https://www.mdpi.com/2072-4292/12/24/4033/htm#sec5-remotesensing-12-04033" target="_blank">Section 5</a> of the following paper:</b>
#     <div style="margin-left: 10px; margin-right: 10px; margin-top:10px">
#       <p> Ferreira, K.R.; Queiroz, G.R.; Vinhas, L.; Marujo, R.F.B.; Simoes, R.E.O.; Picoli, M.C.A.; Camara, G.; Cartaxo, R.; Gomes, V.C.F.; Santos, L.A.; Sanchez, A.H.; Arcanjo, J.S.; Fronza, J.G.; Noronha, C.A.; Costa, R.W.; Zaglia, M.C.; Zioti, F.; Korting, T.S.; Soares, A.R.; Chaves, M.E.D.; Fonseca, L.M.G. 2020. Earth Observation Data Cubes for Brazil: Requirements, Methodology and Products. Remote Sens. 12, no. 24: 4033. DOI: <a href="https://doi.org/10.3390/rs12244033" target="_blank">10.3390/rs12244033</a>. </p>
#       <p> Zioti, F.; Gomes, V.C.F.; Ferreira, K.R.; Queiroz, G.R.; Rodriguez, E. L. 2019. Um ambiente para acesso e análise de trajetórias de uso e cobertura da Terra. Anais do XIX Simpósio Brasileiro de Sensoriamento Remoto.São José dos Campos, INPE, 2019. <a href="https://proceedings.science/sbsr-2019/papers/um-ambiente-para-acesso-e-analise-de-trajetorias-de-uso-e-cobertura-da-terra" target="_blank"> Online </a>. </p>
#     </div>
# </div>

# %% [markdown]
# # Introduction
# <hr style="border:1px solid #0077b9;">

# %% [markdown]
# The **W**eb **L**and **T**rajectory **S**ervice (WLTS) is a web service designed to access and retrieve trajectories of land use and coverage from different type of data sources. Through a simple API, it brings the concept of Land Use and Cover Trajectories as a high level abstraction. Given a location and a time interval you can retrieve the land trajectory from many data collections, including information from the PRODES, DETER, and TerraClass projects.
#
# `Figure 1` shows an example of representation of land use and cover trajectories extracted from a set of classified images, temporally ordered:
#
#
# <center>
#     <img src="https://raw.githubusercontent.com/brazil-data-cube/code-gallery/master/img/wlts/trajectory_def.png" width="600" />,
#     <br/>
#     <b>Figure 1</b> - Land use and cover Trajectory.
# </center>
#
# The WLTS introduces the following concepts:
#
# - **Collections**: refers to a specific dataset from a given data source. A collection can be either represented by vector or raster structures. It has a time interval delimited by time (tmin, tmax). In this way, each Collection has an associated time attribute, which is aligned according to the time granularity of each project that makes the Collection available.
#
# - **Class**: It is the label associated with a particular data item, which corresponds to the specific types of land use or cover, defined by the data source classification system. A Collection consists of a set of Class.
#
# - **Trajectory**: Given a spatial location (x, y), a trajectory is represented by a set of observations that contains the land use and land cover class, the name of collection and time associated with an x, y location in space.
#
# WLTS is based on three operations:
#
# - ``list_collections``: returns the list of collections available in the service.
#
# - ``describe_collection``: returns the metadata of a given data collection.
#
# - ``trajectory``: returns the land use and cover trajectory from the collections given a location in space. The property result contains the feature identifier information, class, time, and the collection associated to the data item.
#
# This Jupyter Notebook shows how to use the [Python Client Library](https://github.com/brazil-data-cube/wlts.py) for Web Land Trajectory Service.

# %% [markdown]
# # Python Client API
# <hr style="border:1px solid #0077b9;">

# %% [markdown]
# For running the examples in this Jupyter Notebook you will need to install the [WLTS client for Python](https://github.com/brazil-data-cube/wlts.py).To install it from PyPI using pip, use the following command:

# %%
pip install git+https://github.com/brazil-data-cube/wlts.py@v1.0.1
# Out:
# Collecting git+https://github.com/brazil-data-cube/wlts.py@v1.0.1
#   Cloning https://github.com/brazil-data-cube/wlts.py (to revision v1.0.1) to /tmp/pip-req-build-8dy347nu
#   Running command git clone --filter=blob:none --quiet https://github.com/brazil-data-cube/wlts.py /tmp/pip-req-build-8dy347nu
#   Running command git checkout -q cfbd23b0e7c7f97495ee363c22d0601061ee46d1
#   Resolved https://github.com/brazil-data-cube/wlts.py to commit cfbd23b0e7c7f97495ee363c22d0601061ee46d1
#   Preparing metadata (setup.py) ... done
# Collecting lccs@ git+https://github.com/brazil-data-cube/lccs.py@v0.8.2 (from wlts==1.0.1)
#   Cloning https://github.com/brazil-data-cube/lccs.py (to revision v0.8.2) to /tmp/pip-install-c2nybtlq/lccs_5468e76d76824492ae191255d8762c4c
#   Running command git clone --filter=blob:none --quiet https://github.com/brazil-data-cube/lccs.py /tmp/pip-install-c2nybtlq/lccs_5468e76d76824492ae191255d8762c4c
#   Running command git checkout -q 41c9bd46a5806bf016fb63326464ad88336a8e37
#   Resolved https://github.com/brazil-data-cube/lccs.py to commit 41c9bd46a5806bf016fb63326464ad88336a8e37
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.20 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wlts==1.0.1) (2.31.0)
# Requirement already satisfied: Click>=7.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wlts==1.0.1) (8.1.7)
# Requirement already satisfied: Jinja2>=2.11.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wlts==1.0.1) (3.1.3)
# Requirement already satisfied: descartes>=1.1.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wlts==1.0.1) (1.1.0)
# Requirement already satisfied: shapely>=1.7.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wlts==1.0.1) (2.0.1)
# Requirement already satisfied: pandas>=1.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wlts==1.0.1) (2.2.2)
# Requirement already satisfied: geopandas>=0.8.2 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wlts==1.0.1) (0.14.3)
# Requirement already satisfied: plotly==5.5.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wlts==1.0.1) (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from plotly==5.5.0->wlts==1.0.1) (8.2.3)
# Requirement already satisfied: six in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from plotly==5.5.0->wlts==1.0.1) (1.16.0)
# Requirement already satisfied: matplotlib in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from descartes>=1.1.0->wlts==1.0.1) (3.8.4)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from geopandas>=0.8.2->wlts==1.0.1) (1.9.4)
# Requirement already satisfied: packaging in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from geopandas>=0.8.2->wlts==1.0.1) (24.0)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from geopandas>=0.8.2->wlts==1.0.1) (3.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from Jinja2>=2.11.1->wlts==1.0.1) (2.1.5)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from pandas>=1.1->wlts==1.0.1) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from pandas>=1.1->wlts==1.0.1) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from pandas>=1.1->wlts==1.0.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from pandas>=1.1->wlts==1.0.1) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from requests>=2.20->wlts==1.0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from requests>=2.20->wlts==1.0.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from requests>=2.20->wlts==1.0.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from requests>=2.20->wlts==1.0.1) (2024.2.2)
# Requirement already satisfied: jsonschema>=3.2 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from lccs@ git+https://github.com/brazil-data-cube/lccs.py@v0.8.2->wlts==1.0.1) (4.21.1)
# Requirement already satisfied: cachetools>=4.2.4 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from lccs@ git+https://github.com/brazil-data-cube/lccs.py@v0.8.2->wlts==1.0.1) (5.3.3)
# Requirement already satisfied: lxml>=4.9.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from lccs@ git+https://github.com/brazil-data-cube/lccs.py@v0.8.2->wlts==1.0.1) (5.2.2)
# Requirement already satisfied: python-sld==1.0.10 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from lccs@ git+https://github.com/brazil-data-cube/lccs.py@v0.8.2->wlts==1.0.1) (1.0.10)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas>=0.8.2->wlts==1.0.1) (23.2.0)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas>=0.8.2->wlts==1.0.1) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas>=0.8.2->wlts==1.0.1) (0.7.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from jsonschema>=3.2->lccs@ git+https://github.com/brazil-data-cube/lccs.py@v0.8.2->wlts==1.0.1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from jsonschema>=3.2->lccs@ git+https://github.com/brazil-data-cube/lccs.py@v0.8.2->wlts==1.0.1) (0.35.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from jsonschema>=3.2->lccs@ git+https://github.com/brazil-data-cube/lccs.py@v0.8.2->wlts==1.0.1) (0.18.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib->descartes>=1.1.0->wlts==1.0.1) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib->descartes>=1.1.0->wlts==1.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib->descartes>=1.1.0->wlts==1.0.1) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib->descartes>=1.1.0->wlts==1.0.1) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib->descartes>=1.1.0->wlts==1.0.1) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib->descartes>=1.1.0->wlts==1.0.1) (3.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
#  In order to access the funcionalities of the client API, you should import the `wlts` package, as follows:

# %%
import wlts

# %% [markdown]
# After that, you can check the installed version of WLTS client package:

# %%
wlts.__version__
# Out:
# '1.0.1'

# %% [markdown]
# WLTS is a client-server service. On the server-side, the data is stored, which is accessible through each of the API operations, described earlier. On the client-side (what this tutorial covers), you can use the operations and consume the data. In this tutorial, we will use the Python client to access the data. We need to define the URL where the WLTS server is operating. The code below defines the URL of the WLTS server. You should create a wlts object attached to a given service:

# %%
service = wlts.WLTS('https://data.inpe.br/bdc/wlts/v1')

# %% [markdown]
# The above cell will create an object named `service` that will allow us to comunicate to the given WLTS service.

# %% [markdown]
# # Listing the Available Collections
# <hr style="border:1px solid #0077b9;">

# %% [markdown]
# In WLTS, datasets that aggregate features from different classification systems, which various projects can generate, are represented through collections. Thus, the first operation presented is `list_collections`. This operation returns the list of all data collections that are available in the WLTS. In the  WLTS client for Python, this operation is used via the ``list_collections`` method which return a list of collection names:

# %%
service.collections
# Out:
# ['prodes_pantanal',
#  'ibge_cobertura_uso_terra',
#  'deter_amazonia_legal',
#  'prodes_pampa',
#  'prodes_mata_atlantica',
#  'deter_cerrado',
#  'prodes_amazonia_legal',
#  'prodes_caatinga',
#  'terraclass_amazonia',
#  'prodes_cerrado',
#  'lapig_areas_pastagem',
#  'terraclass_amazonia-v2',
#  'terraclass_cerrado',
#  'terraclass_amazonia-v3',
#  'mapbiomas-v8']

# %% [markdown]
# The names returned can be used in subsequent operations.

# %% [markdown]
# # Retrieving the Metadata of a collection
# <hr style="border:1px solid #0077b9;">

# %% [markdown]
# Each collection is associated with a set of metadata that describes it. In WLTS a, there is the ``describe_collection`` operation, which allows the retrieval of this information. It is possible to access the metadata of a specific collection with the `operator[]`:

# %% [markdown]
# > The example below retrieves the metadata from the collection named prodes_cerrado

# %%
service['prodes_cerrado']
# Out:
# Collection(service=wlts(url="https://data.inpe.br/bdc/wlts/v1"), metadata={'classification_system': {'id': None, 'name': None, 'title': None, 'type': 'Self', 'version': None}, 'collection_type': 'Feature', 'datasource': {'host': 'https://terrabrasilis.dpi.inpe.br/geoserver', 'layers': [{'data_field': 'year', 'layer_name': 'residual', 'title': 'Residual', 'workspace': 'prodes-cerrado-nb'}, {'data_field': 'year', 'layer_name': 'accumulated_deforestation_2000', 'title': 'Accumulated Deforestation 2000', 'workspace': 'prodes-cerrado-nb'}, {'data_field': 'year', 'layer_name': 'yearly_deforestation', 'title': 'Yearly Deforestation', 'workspace': 'prodes-cerrado-nb'}]}, 'deprecated': False, 'description': 'PRODES Cerrado que consiste no mapeamento do desmatamento para toda extensão do Cerrado.', 'detail': 'O Brasil se viu encorajado a estruturar um sistema oficial de monitoramento sistemático do desmatamento para esta região. Neste contexto, o Instituto Nacional de Pesquisas Espaciais (INPE) está divulgando os resultados do projeto PRODES Cerrado que consiste no mapeamento do desmatamento para toda extensão do Cerrado de 2000 a 2018. Por meio do projeto foi construída uma séria histórica bienal da remoção antrópica da vegetação natural para o período de 2000 a 2012 e anual para os anos de 2013 a 2021. Mais informações: http://cerrado.obt.inpe.br/', 'is_public': True, 'name': 'prodes_cerrado', 'period': {'end_date': '2022', 'start_date': '2000'}, 'spatial_extent': {'xmax': -24.6851196289062, 'xmin': -60.0939559936523, 'ymax': -2.32670903205872, 'ymin': -41.5224685668945}, 'temporal_resolution': {'unit': 'YEAR', 'value': 1}, 'title': 'PRODES Cerrado'}

# %% [markdown]
# # Retrieving the Trajectory
# <hr style="border:1px solid #0077b9;">

# %% [markdown]
# In WLTS, since a collection is associated with a dataset with time variation, it is possible to retrieve the land use and land cover trajectory of a given point. The figure below illustrates this process.

# %% [markdown]
# <center>
#     <img src="https://raw.githubusercontent.com/brazil-data-cube/code-gallery/master/img/wlts/traj1.png" width="750" />,
#     <br/>
#     <b>Figure 2</b> - WLTS trajectory extraction.
# </center>

# %% [markdown]
# In order to retrieve the trajectory in the location of `latitude -12.0` and `longitude -54.0` use the `tj` method:

# %%
tj = service.tj(latitude=-12.0, longitude=-54.0, collections='mapbiomas-v8')

# %%
tj
# Out:
# {'query': {'collections': ['mapbiomas-v8'],
#   'end_date': '',
#   'geometry': '',
#   'language': 'pt-br',
#   'latitude': -12.0,
#   'longitude': -54.0,
#   'start_date': ''},
#  'result': {'trajectory': [{'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1985',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1986',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1987',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1988',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1989',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1990',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1991',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1992',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1993',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1994',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1995',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1996',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1997',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1998',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1999',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2000',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2001',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2002',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2003',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2004',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2005',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2006',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2007',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2008',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2009',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2010',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2011',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2012',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2013',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2014',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2015',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2016',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2017',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2018',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2019',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2020',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2021',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2022',
#     'point_id': 1}]}}

# %% [markdown]
# > The coordinates in the request must be in EPSG:4326

# %% [markdown]
# WLTS allows more than one collection to be accessed at the same time for the same point. By doing this, a trajectory for each project will be extracted. This way of operation is illustrated by the figure below.

# %% [markdown]
# <center>
#     <img src="https://raw.githubusercontent.com/brazil-data-cube/code-gallery/master/img/wlts/traj2.png" width="750" />,
#     <br/>
#     <b>Figure 3</b> - WLTS trajectory extraction using multiple collections.
# </center>

# %% [markdown]
# The names are entered in the collections parameter and must be separated by a comma. As an example, the code below retrieves the trajectories considering the collections ``mapbiomas_amazonia-v5`` and ``terraclass_amazonia.``

# %%
tj_multiples_collections = service.tj(latitude=-12.0, longitude=-54.0, collections='mapbiomas-v8,terraclass_amazonia-v3')

# %%
tj_multiples_collections
# Out:
# {'query': {'collections': ['mapbiomas-v8', 'terraclass_amazonia-v3'],
#   'end_date': '',
#   'geometry': '',
#   'language': 'pt-br',
#   'latitude': -12.0,
#   'longitude': -54.0,
#   'start_date': ''},
#  'result': {'trajectory': [{'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1985',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1986',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1987',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1988',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1989',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1990',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1991',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1992',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1993',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1994',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1995',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1996',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1997',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1998',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '1999',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2000',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2001',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2002',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2003',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2004',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2005',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2006',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2007',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2008',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2009',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2010',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2011',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2012',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2013',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2014',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2015',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2016',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2017',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2018',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2019',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2020',
#     'point_id': 1},
#    {'class': 'Vegetação Natural Florestal Primária',
#     'collection': 'terraclass_amazonia-v3',
#     'date': '2020',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2021',
#     'point_id': 1},
#    {'class': 'Formação Florestal',
#     'collection': 'mapbiomas-v8',
#     'date': '2022',
#     'point_id': 1}]}}

# %% [markdown]
# It is possible to retrieve the land use and land cover trajectory of a multiples point. The code below illustrates this process.

# %%
tj_m = service.tj(latitude=[-8.485646, -12.0], longitude=[-56.869833, -54.0], collections='mapbiomas-v8')
tj_m
# Out:
# {'trajectories': [{'query': {'collections': ['mapbiomas-v8'],
#     'end_date': '',
#     'geometry': '',
#     'language': 'pt-br',
#     'latitude': -8.485646,
#     'longitude': -56.869833,
#     'start_date': ''},
#    'result': {'trajectory': [{'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1985',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1986',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1987',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1988',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1989',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1990',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1991',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1992',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1993',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1994',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1995',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1996',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1997',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1998',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1999',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2000',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2001',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2002',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2003',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2004',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2005',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2006',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2007',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2008',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2009',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2010',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2011',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2012',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2013',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2014',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2015',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2016',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2017',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2018',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2019',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2020',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2021',
#       'point_id': 1},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2022',
#       'point_id': 1}]}},
#   {'query': {'collections': ['mapbiomas-v8'],
#     'end_date': '',
#     'geometry': '',
#     'language': 'pt-br',
#     'latitude': -12.0,
#     'longitude': -54.0,
#     'start_date': ''},
#    'result': {'trajectory': [{'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1985',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1986',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1987',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1988',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1989',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1990',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1991',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1992',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1993',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1994',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1995',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1996',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1997',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1998',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '1999',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2000',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2001',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2002',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2003',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2004',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2005',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2006',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2007',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2008',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2009',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2010',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2011',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2012',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2013',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2014',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2015',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2016',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2017',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2018',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2019',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2020',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2021',
#       'point_id': 2},
#      {'class': 'Formação Florestal',
#       'collection': 'mapbiomas-v8',
#       'date': '2022',
#       'point_id': 2}]}}]}

# %% [markdown]
# # Visualizing the Trajectory with Pandas
# <hr style="border:1px solid #0077b9;">

# %% [markdown]
# If you have Pandas installed, it is possible to plot the trajectory with the `df` method:

# %%
import pandas as pd

# %%
tj.df()
# Out:
#                  class    collection  date  point_id
# 0   Formação Florestal  mapbiomas-v8  1985         1
# 1   Formação Florestal  mapbiomas-v8  1986         1
# 2   Formação Florestal  mapbiomas-v8  1987         1
# 3   Formação Florestal  mapbiomas-v8  1988         1
# 4   Formação Florestal  mapbiomas-v8  1989         1
# 5   Formação Florestal  mapbiomas-v8  1990         1
# 6   Formação Florestal  mapbiomas-v8  1991         1
# 7   Formação Florestal  mapbiomas-v8  1992         1
# 8   Formação Florestal  mapbiomas-v8  1993         1
# 9   Formação Florestal  mapbiomas-v8  1994         1
# 10  Formação Florestal  mapbiomas-v8  1995         1
# 11  Formação Florestal  mapbiomas-v8  1996         1
# 12  Formação Florestal  mapbiomas-v8  1997         1
# 13  Formação Florestal  mapbiomas-v8  1998         1
# 14  Formação Florestal  mapbiomas-v8  1999         1
# 15  Formação Florestal  mapbiomas-v8  2000         1
# 16  Formação Florestal  mapbiomas-v8  2001         1
# 17  Formação Florestal  mapbiomas-v8  2002         1
# 18  Formação Florestal  mapbiomas-v8  2003         1
# 19  Formação Florestal  mapbiomas-v8  2004         1
# 20  Formação Florestal  mapbiomas-v8  2005         1
# 21  Formação Florestal  mapbiomas-v8  2006         1
# 22  Formação Florestal  mapbiomas-v8  2007         1
# 23  Formação Florestal  mapbiomas-v8  2008         1
# 24  Formação Florestal  mapbiomas-v8  2009         1
# 25  Formação Florestal  mapbiomas-v8  2010         1
# 26  Formação Florestal  mapbiomas-v8  2011         1
# 27  Formação Florestal  mapbiomas-v8  2012         1
# 28  Formação Florestal  mapbiomas-v8  2013         1
# 29  Formação Florestal  mapbiomas-v8  2014         1
# 30  Formação Florestal  mapbiomas-v8  2015         1
# 31  Formação Florestal  mapbiomas-v8  2016         1
# 32  Formação Florestal  mapbiomas-v8  2017         1
# 33  Formação Florestal  mapbiomas-v8  2018         1
# 34  Formação Florestal  mapbiomas-v8  2019         1
# 35  Formação Florestal  mapbiomas-v8  2020         1
# 36  Formação Florestal  mapbiomas-v8  2021         1
# 37  Formação Florestal  mapbiomas-v8  2022         1

# %%
trajectory_two = service.tj(latitude=-4.090, longitude=-63.353, collections='mapbiomas-v8')

trajectory_two.df()
# Out:
#                  class    collection  date  point_id
# 0   Rio, Lago e Oceano  mapbiomas-v8  1985         1
# 1   Rio, Lago e Oceano  mapbiomas-v8  1986         1
# 2   Rio, Lago e Oceano  mapbiomas-v8  1987         1
# 3   Rio, Lago e Oceano  mapbiomas-v8  1988         1
# 4   Rio, Lago e Oceano  mapbiomas-v8  1989         1
# 5   Rio, Lago e Oceano  mapbiomas-v8  1990         1
# 6   Rio, Lago e Oceano  mapbiomas-v8  1991         1
# 7   Rio, Lago e Oceano  mapbiomas-v8  1992         1
# 8   Rio, Lago e Oceano  mapbiomas-v8  1993         1
# 9   Rio, Lago e Oceano  mapbiomas-v8  1994         1
# 10  Rio, Lago e Oceano  mapbiomas-v8  1995         1
# 11  Rio, Lago e Oceano  mapbiomas-v8  1996         1
# 12  Rio, Lago e Oceano  mapbiomas-v8  1997         1
# 13  Rio, Lago e Oceano  mapbiomas-v8  1998         1
# 14  Rio, Lago e Oceano  mapbiomas-v8  1999         1
# 15  Rio, Lago e Oceano  mapbiomas-v8  2000         1
# 16  Rio, Lago e Oceano  mapbiomas-v8  2001         1
# 17  Rio, Lago e Oceano  mapbiomas-v8  2002         1
# 18  Rio, Lago e Oceano  mapbiomas-v8  2003         1
# 19  Rio, Lago e Oceano  mapbiomas-v8  2004         1
# 20  Rio, Lago e Oceano  mapbiomas-v8  2005         1
# 21  Rio, Lago e Oceano  mapbiomas-v8  2006         1
# 22  Rio, Lago e Oceano  mapbiomas-v8  2007         1
# 23  Rio, Lago e Oceano  mapbiomas-v8  2008         1
# 24  Rio, Lago e Oceano  mapbiomas-v8  2009         1
# 25  Rio, Lago e Oceano  mapbiomas-v8  2010         1
# 26  Rio, Lago e Oceano  mapbiomas-v8  2011         1
# 27  Rio, Lago e Oceano  mapbiomas-v8  2012         1
# 28  Rio, Lago e Oceano  mapbiomas-v8  2013         1
# 29  Rio, Lago e Oceano  mapbiomas-v8  2014         1
# 30  Rio, Lago e Oceano  mapbiomas-v8  2015         1
# 31  Rio, Lago e Oceano  mapbiomas-v8  2016         1
# 32  Rio, Lago e Oceano  mapbiomas-v8  2017         1
# 33  Rio, Lago e Oceano  mapbiomas-v8  2018         1
# 34  Rio, Lago e Oceano  mapbiomas-v8  2019         1
# 35  Rio, Lago e Oceano  mapbiomas-v8  2020         1
# 36  Rio, Lago e Oceano  mapbiomas-v8  2021         1
# 37  Rio, Lago e Oceano  mapbiomas-v8  2022         1

# %%
trajectory_three = service.tj(latitude=-10.710, longitude=-55.612, collections='mapbiomas-v8')

trajectory_three.df()
# Out:
#                            class    collection  date  point_id
# 0                       Pastagem  mapbiomas-v8  1985         1
# 1                       Pastagem  mapbiomas-v8  1986         1
# 2                       Pastagem  mapbiomas-v8  1987         1
# 3                       Pastagem  mapbiomas-v8  1988         1
# 4                       Pastagem  mapbiomas-v8  1989         1
# 5                       Pastagem  mapbiomas-v8  1990         1
# 6                       Pastagem  mapbiomas-v8  1991         1
# 7                       Pastagem  mapbiomas-v8  1992         1
# 8                       Pastagem  mapbiomas-v8  1993         1
# 9                       Pastagem  mapbiomas-v8  1994         1
# 10                      Pastagem  mapbiomas-v8  1995         1
# 11                      Pastagem  mapbiomas-v8  1996         1
# 12                      Pastagem  mapbiomas-v8  1997         1
# 13                      Pastagem  mapbiomas-v8  1998         1
# 14                      Pastagem  mapbiomas-v8  1999         1
# 15                      Pastagem  mapbiomas-v8  2000         1
# 16                      Pastagem  mapbiomas-v8  2001         1
# 17                      Pastagem  mapbiomas-v8  2002         1
# 18                      Pastagem  mapbiomas-v8  2003         1
# 19                      Pastagem  mapbiomas-v8  2004         1
# 20                      Pastagem  mapbiomas-v8  2005         1
# 21                      Pastagem  mapbiomas-v8  2006         1
# 22                      Pastagem  mapbiomas-v8  2007         1
# 23                      Pastagem  mapbiomas-v8  2008         1
# 24                      Pastagem  mapbiomas-v8  2009         1
# 25                      Pastagem  mapbiomas-v8  2010         1
# 26                      Pastagem  mapbiomas-v8  2011         1
# 27                      Pastagem  mapbiomas-v8  2012         1
# 28                      Pastagem  mapbiomas-v8  2013         1
# 29  Outras Lavouras Temporárias   mapbiomas-v8  2014         1
# 30  Outras Lavouras Temporárias   mapbiomas-v8  2015         1
# 31  Outras Lavouras Temporárias   mapbiomas-v8  2016         1
# 32                          Soja  mapbiomas-v8  2017         1
# 33                          Soja  mapbiomas-v8  2018         1
# 34                          Soja  mapbiomas-v8  2019         1
# 35                          Soja  mapbiomas-v8  2020         1
# 36                          Soja  mapbiomas-v8  2021         1
# 37                          Soja  mapbiomas-v8  2022         1

# %% [markdown]
# To recover the ``geometries`` that intercept the location informed in the land use and cover trajectory operation, the parameter ``geometry=True`` must be passed. See example in the code below:

# %%
trajectory_geometry = service.tj(latitude=-12.0, longitude=-54.0, collections='ibge_cobertura_uso_terra', geometry=True)

# %% [markdown]
# This operation will return a new field: **geom**. This field contains the geometry in ``WKT`` in ``EPSG: 4326`` It is possible to plot the trajectory with the ``geodf`` method:

# %%
trajectory_geometry.geodf()
# Out:
#                   class                collection  date  \
# 0   Vegetação Florestal  ibge_cobertura_uso_terra  2000
# 1   Vegetação Florestal  ibge_cobertura_uso_terra  2000
# 2   Vegetação Florestal  ibge_cobertura_uso_terra  2010
# 3   Vegetação Florestal  ibge_cobertura_uso_terra  2010
# 4   Vegetação Florestal  ibge_cobertura_uso_terra  2012
# 5   Vegetação Florestal  ibge_cobertura_uso_terra  2012
# 6   Vegetação Florestal  ibge_cobertura_uso_terra  2014
# 7   Vegetação Florestal  ibge_cobertura_uso_terra  2014
# 8   Vegetação Florestal  ibge_cobertura_uso_terra  2016
# 9   Vegetação Florestal  ibge_cobertura_uso_terra  2016
# 10  Vegetação Florestal  ibge_cobertura_uso_terra  2018
# 11  Vegetação Florestal  ibge_cobertura_uso_terra  2018
#
#                                                  geom  point_id
# 0   POLYGON ((-53.99070 -12.00890, -54.00000 -12.0...         1
# 1   POLYGON ((-54.00000 -12.00890, -54.00930 -12.0...         1
# 2   POLYGON ((-53.99070 -12.00890, -54.00000 -12.0...         1
# 3   POLYGON ((-54.00000 -12.00890, -54.00930 -12.0...         1
# 4   POLYGON ((-53.99070 -12.00890, -54.00000 -12.0...         1
# 5   POLYGON ((-54.00000 -12.00890, -54.00930 -12.0...         1
# 6   POLYGON ((-53.99070 -12.00890, -54.00000 -12.0...         1
# 7   POLYGON ((-54.00000 -12.00890, -54.00930 -12.0...         1
# 8   POLYGON ((-53.99070 -12.00890, -54.00000 -12.0...         1
# 9   POLYGON ((-54.00000 -12.00890, -54.00930 -12.0...         1
# 10  POLYGON ((-53.99070 -12.00890, -54.00000 -12.0...         1
# 11  POLYGON ((-54.00000 -12.00890, -54.00930 -12.0...         1

# %% [markdown]
# # References
# <hr style="border:1px solid #0077b9;">

# %% [markdown]
# - [Python Client Library for Web Land Trajectory Service - User Guide](https://wlts.readthedocs.io/en/latest/index.html)
#
#
# - [Python Client Library for Web Land Trajectory Service - GitHub Repository](https://github.com/brazil-data-cube/wlts.py)
#
#
# - [WLTS OpenAPI 3 Specification](https://github.com/brazil-data-cube/wlts-spec)
#
#
# - [WLTS Server](https://github.com/brazil-data-cube/wlts)
