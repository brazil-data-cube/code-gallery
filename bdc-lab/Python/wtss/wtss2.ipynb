# %% [markdown]
# # WTSS Python Client - Notebook example

# %%
# !pip install git+https://github.com/brazil-data-cube/wtss.py@b-2.0
# Out:
# Collecting git+https://github.com/brazil-data-cube/wtss.py@b-2.0
#   Cloning https://github.com/brazil-data-cube/wtss.py (to revision b-2.0) to /tmp/pip-req-build-2lmj07zh
#   Running command git clone --filter=blob:none --quiet https://github.com/brazil-data-cube/wtss.py /tmp/pip-req-build-2lmj07zh
#   Running command git checkout -b b-2.0 --track origin/b-2.0
#   Switched to a new branch 'b-2.0'
#   Branch 'b-2.0' set up to track remote branch 'b-2.0' from 'origin'.
#   Resolved https://github.com/brazil-data-cube/wtss.py to commit 2fc8e8da6767d7185196fe3b652abb1b5538704f
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click>=7.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wtss==2.0.0a2) (8.1.7)
# Requirement already satisfied: jsonschema>=3.2 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wtss==2.0.0a2) (4.21.1)
# Requirement already satisfied: requests>=2.20 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wtss==2.0.0a2) (2.31.0)
# Requirement already satisfied: Jinja2>=2.10 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wtss==2.0.0a2) (3.1.3)
# Requirement already satisfied: python-dateutil>=2.8 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wtss==2.0.0a2) (2.9.0)
# Requirement already satisfied: Shapely>=1.8 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from wtss==2.0.0a2) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from Jinja2>=2.10->wtss==2.0.0a2) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from jsonschema>=3.2->wtss==2.0.0a2) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from jsonschema>=3.2->wtss==2.0.0a2) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from jsonschema>=3.2->wtss==2.0.0a2) (0.35.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from jsonschema>=3.2->wtss==2.0.0a2) (0.18.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from python-dateutil>=2.8->wtss==2.0.0a2) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from requests>=2.20->wtss==2.0.0a2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from requests>=2.20->wtss==2.0.0a2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from requests>=2.20->wtss==2.0.0a2) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from requests>=2.20->wtss==2.0.0a2) (2024.2.2)
# Requirement already satisfied: numpy>=1.14 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from Shapely>=1.8->wtss==2.0.0a2) (1.26.4)
# Building wheels for collected packages: wtss
#   Building wheel for wtss (setup.py) ... done
#   Created wheel for wtss: filename=wtss-2.0.0a2-py3-none-any.whl size=37774 sha256=34a3f0f214e9c9bb0d59d9f066610935b25777f15049e06aec2a9e3412150d3b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-livj5hmz/wheels/68/cf/92/944061dcb2321f6ea505f70f180c6b41b418cf31acde9544ba
# Successfully built wtss
# Installing collected packages: wtss
#   Attempting uninstall: wtss
#     Found existing installation: wtss 0.7.1
#     Uninstalling wtss-0.7.1:
#       Successfully uninstalled wtss-0.7.1
# Successfully installed wtss-2.0.0a2

# %%
# !pip install geopandas numpy matplotlib
# Out:
# Requirement already satisfied: geopandas in /opt/conda/envs/geospatial/lib/python3.11/site-packages (0.14.3)
# Requirement already satisfied: numpy in /opt/conda/envs/geospatial/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /opt/conda/envs/geospatial/lib/python3.11/site-packages (3.8.4)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from geopandas) (1.9.4)
# Requirement already satisfied: packaging in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from geopandas) (24.0)
# Requirement already satisfied: pandas>=1.4.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (23.2.0)
# Requirement already satisfied: certifi in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (2024.2.2)
# Requirement already satisfied: click~=8.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/geospatial/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2024.1)

# %% [markdown]
# ## Connect to WTSS server

# %%
from wtss import WTSS
import os

service = WTSS('https://data.inpe.br/bdc/wtss/v4/')
service
# Out:
# wtss(url="http://senegal.coids.inpe.br/bdc/wtss/v4/",validate=False,access_token=None)

# %%
import wtss
wtss.__version__
# Out:
# '2.0.0-alpha2'

# %% [markdown]
# ## Select the data cube Sentinel-2 16 days

# %%
coverage = service['S2-16D-2']
coverage
# Out:
# <div>
#     <div>
#         <b>Coverage Name:</b> S2-16D-2
#     </div>
#     <br/>
#     <div>
#         <b>Description:</b> Earth Observation Data Cube generated from Copernicus Sentinel-2/MSI Level-2A product over Brazil. This dataset is provided in Cloud Optimized GeoTIFF (COG) file format. The dataset is processed with 10 meters of spatial resolution, reprojected and cropped to BDC_SM grid Version 2 (BDC_SM V2), considering a temporal compositing function of 16 days using the Least Cloud Cover First (LCF) best pixel approach.
#     </div>
#     <br/>
#     <div>
#         <b>Attributes:</b>
#     </div>
#     <div>
#         <table>
#             <tr>
#             </tr>
#             <tr>
#                 <th>name</th>
#                 <th>common name</th>
#                 <th>description</th>
#                 <th>min</th>
#                 <th>max</th>
#                 <th>nodata</th>
#                 <th>scale</th>
#                 <th>center_wavelength</th>
#                 <th>full_width_half_max</th>
#                 <th>data_type</th>
#             </tr>
#             <tr>
#                 <td>CLEAROB</td>
#                 <td>ClearOb</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>1.0</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint8</td>
#             </tr><tr>
#                 <td>TOTALOB</td>
#                 <td>TotalOb</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>1.0</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint8</td>
#             </tr><tr>
#                 <td>PROVENANCE</td>
#                 <td>Provenance</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>-1.0</td>
#                 <td>1.0</td>
#                 <td></td>
#                 <td></td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>SCL</td>
#                 <td>quality</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>1.0</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint8</td>
#             </tr><tr>
#                 <td>B01</td>
#                 <td>coastal</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>B02</td>
#                 <td>blue</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>B04</td>
#                 <td>red</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>B05</td>
#                 <td>rededge</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>B06</td>
#                 <td>rededge</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>B07</td>
#                 <td>rededge</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>B08</td>
#                 <td>nir</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>B8A</td>
#                 <td>nir08</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>B09</td>
#                 <td>nir09</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>B03</td>
#                 <td>green</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>B11</td>
#                 <td>swir16</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>B12</td>
#                 <td>swir22</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>EVI</td>
#                 <td>evi</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>-9999.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>NDVI</td>
#                 <td>ndvi</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>-9999.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>NBR</td>
#                 <td>nbr</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>-9999.0</td>
#                 <td>0.0001</td>
#                 <td></td>
#                 <td></td>
#                 <td>int16</td>
#             </tr>
#         </table>
#     </div>
#     </br>
#     <div>
#         <b>Extent</b>
#     </div>
#     <div>
#         <table>
#             <tr>
#                 <th>xmin</th>
#                 <th>ymin</th>
#                 <th>xmax</th>
#                 <th>ymax</th>
#             </tr>
#              <tr>
#                  <td>-74.871069</td>
#                  <td>-34.67556459214432</td>
#                  <td>-28.006208041654325</td>
#                  <td>5.763264005526926</td>
#              </tr>
#         </table>
#     </div>
#     <br/>
#     <div>
#         <b>Timeline</b>
#     </div>
#         <select id="timeline" size="10">
#         <option value="{d}">2018-01-01</option><option value="{d}">2018-01-17</option><option value="{d}">2018-02-02</option><option value="{d}">2018-02-18</option><option value="{d}">2018-03-06</option><option value="{d}">2018-03-22</option><option value="{d}">2018-04-07</option><option value="{d}">2018-04-23</option><option value="{d}">2018-05-09</option><option value="{d}">2018-05-25</option><option value="{d}">2018-06-10</option><option value="{d}">2018-06-26</option><option value="{d}">2018-07-12</option><option value="{d}">201

# %% [markdown]
# _______________________________________
# ## 3) Timeseries: The user can retrieve all timeseries inside the geometry

# %%
import shapely.geometry

timeseries = coverage.ts(attributes=('NDVI',),
                         geom=shapely.geometry.box(-59.60, -5.69, -59.59, -5.68),
                         start_datetime="2020-01-01", end_datetime="2022-12-31")

timeseries
# Out:
# TimeSeriesSearch(coverage=Coverage(service=wtss(url="http://senegal.coids.inpe.br/bdc/wtss/v4/",validate=False,access_token=None), id=S2-16D-2), query=TimeSeriesQuery(params={}, attributes=('NDVI',), start_datetime='2020-01-01T00:00:00Z', end_datetime='2022-12-31T00:00:00Z', geom=<POLYGON ((-59.59 -5.69, -59.59 -5.68, -59.6 -5.68, -59.6 -5.69, -59.59 -5.69))>, pagination='P3M'), _pagination=None, _ts=None, _df=None)

# %% [markdown]
# ### 3.1) The query results are available as timeseries properties:

# %%
# Show total of locations matched
total = timeseries.total_locations()
total
# Out:
# 12995

# %% [markdown]
# ### 3.2) The user can plot the time series for each pixel

# %%
timeseries.plot()

# %% [markdown]
# ### 3.3) All values from each datetime and each attribute are available in a pandas dataframe format

# %%
timeseries_df = timeseries.df()
timeseries_df
# Out:
#        attribute                    geometry   value   datetime
# 0           NDVI  POINT (-59.60014 -5.67962) -0.0602 2020-01-01
# 1           NDVI  POINT (-59.60014 -5.67962)  0.5791 2020-01-17
# 2           NDVI  POINT (-59.60014 -5.67962)  0.8073 2020-02-02
# 3           NDVI  POINT (-59.60014 -5.67962)  0.8232 2020-02-18
# 4           NDVI  POINT (-59.60014 -5.67962)  0.1098 2020-03-05
# ...          ...                         ...     ...        ...
# 896650      NDVI  POINT (-59.59015 -5.69004)  0.1489 2022-10-16
# 896651      NDVI  POINT (-59.59015 -5.69004)  0.8104 2022-11-01
# 896652      NDVI  POINT (-59.59015 -5.69004) -0.0438 2022-11-17
# 896653      NDVI  POINT (-59.59015 -5.69004)  0.7842 2022-12-03
# 896654      NDVI  POINT (-59.59015 -5.69004)  0.1985 2022-12-19
#
# [896655 rows x 4 columns]

# %% [markdown]
# _______________________________________
# ## 4) Summarize: The user can retrieve summarized timeseries from a geometry (e.g. mean, median, min, max, std)

# %%
summarize = timeseries.summarize()
summarize
# Out:
# <div>
#     <div>
#         <b>Summarize:</b> S2-16D-2
#     </div>
#
#
#     <br/>
#
#
#     <!-- Print the timeline -->
#     <div>
#         <b>timeline</b>
#     </div>
#     <div>
#         <select id="timeline" size="10">
#         <option value="{d}">2020-01-01</option><option value="{d}">2020-01-17</option><option value="{d}">2020-02-02</option><option value="{d}">2020-02-18</option><option value="{d}">2020-03-05</option><option value="{d}">2020-03-21</option><option value="{d}">2020-04-06</option><option value="{d}">2020-04-22</option><option value="{d}">2020-05-08</option><option value="{d}">2020-05-24</option><option value="{d}">2020-06-09</option><option value="{d}">2020-06-25</option><option value="{d}">2020-07-11</option><option value="{d}">2020-07-27</option><option value="{d}">2020-08-12</option><option value="{d}">2020-08-28</option><option value="{d}">2020-09-13</option><option value="{d}">2020-09-29</option><option value="{d}">2020-10-15</option><option value="{d}">2020-10-31</option><option value="{d}">2020-11-16</option><option value="{d}">2020-12-02</option><option value="{d}">2020-12-18</option><option value="{d}">2021-01-01</option><option value="{d}">2021-01-17</option><option value="{d}">2021-02-02</option><option value="{d}">2021-02-18</option><option value="{d}">2021-03-06</option><option value="{d}">2021-03-22</option><option value="{d}">2021-04-07</option><option value="{d}">2021-04-23</option><option value="{d}">2021-05-09</option><option value="{d}">2021-05-25</option><option value="{d}">2021-06-10</option><option value="{d}">2021-06-26</option><option value="{d}">2021-07-12</option><option value="{d}">2021-07-28</option><option value="{d}">2021-08-13</option><option value="{d}">2021-08-29</option><option value="{d}">2021-09-14</option><option value="{d}">2021-09-30</option><option value="{d}">2021-10-16</option><option value="{d}">2021-11-01</option><option value="{d}">2021-11-17</option><option value="{d}">2021-12-03</option><option value="{d}">2021-12-19</option><option value="{d}">2022-01-01</option><option value="{d}">2022-01-17</option><option value="{d}">2022-02-02</option><option value="{d}">2022-02-18</option><option value="{d}">2022-03-06</option><option value="{d}">2022-03-22</option><option value="{d}">2022-04-07</option><option value="{d}">2022-04-23</option><option value="{d}">2022-05-09</option><option value="{d}">2022-05-25</option><option value="{d}">2022-06-10</option><option value="{d}">2022-06-26</option><option value="{d}">2022-07-12</option><option value="{d}">2022-07-28</option><option value="{d}">2022-08-13</option><option value="{d}">2022-08-29</option><option value="{d}">2022-09-14</option><option value="{d}">2022-09-30</option><option value="{d}">2022-10-16</option><option value="{d}">2022-11-01</option><option value="{d}">2022-11-17</option><option value="{d}">2022-12-03</option><option value="{d}">2022-12-19</option>
#         </select>
#     </div>
#
#
#     <br/>
#
#
#     <div>
#         <b>Summarize:</b>
#     </div>
#     <!-- Print the table for each attribute -->
#     <div>
#         <div>
#             <b>NDVI</b>
#         </div>
#         <table>
#             <!-- Set the columns names -->
#             <tr>
#                 <th>datetime</th>
#                 <th>min</th><th>max</th><th>mean</th><th>median</th><th>std</th>
#             </tr>
#
#             <!-- The table data will contain a maximum of 5 items -->
#
#                 <tr>
#
#                         <td>2020-01-01</td>
#                         <td>-0.0983</td><td>-0.0437</td><td>-0.06423856</td><td>-0.0644</td><td>0.00588361</td>
#
#
#                 </tr>
#                 <tr>
#
#                         <td>2020-01-17</td>
#                         <td>0.1225</td><td>0.7697</td><td>0.39516039</td><td>0.3891</td><td>0.08879963</td>
#
#
#                 </tr>
#                 <tr>
#
#                         <td>2020-02-02</td>
#                         <td>0.4424</td><td>0.9041</td><td>0.78797861</td><td>0.8091</td><td>0.07984427</td>
#
#
#                 </tr>
#                 <tr>
#
#                         <td>2020-02-18</td>
#                         <td>0.4065</td><td>0.8481</td><td>0.74342326</td><td>0.7493</td><td>0.05669013</td>
#
#
#                 </tr>
#                 <tr>
#
#                         <td>2020-03-05</td>
#                         <td>0.0346</td><td>0.802</td><td>0.42358789</td><td>0.3949</td><td>0.22579763</td>
#
#
#                 </tr>
#                 <tr>
#
#                         <td>...</td>
#                         <td>...</td><td>...</td><td>...</td><td>...</td><td>...</td>
#
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>
#
#                 </tr>
#                 <tr>

# %% [markdown]
# ### 4.1) The query results are available as timeseries properties:

# %%
print('\n summarize attributes:', summarize.attributes)

print('\n summarize timeline:', summarize.timeline)

print('\n NDVI mean:', summarize.NDVI.mean)
# Out:
#  summarize attributes: ['NDVI']
#
#  summarize timeline: ['2020-01-01', '2020-01-17', '2020-02-02', '2020-02-18', '2020-03-05', '2020-03-21', '2020-04-06', '2020-04-22', '2020-05-08', '2020-05-24', '2020-06-09', '2020-06-25', '2020-07-11', '2020-07-27', '2020-08-12', '2020-08-28', '2020-09-13', '2020-09-29', '2020-10-15', '2020-10-31', '2020-11-16', '2020-12-02', '2020-12-18', '2021-01-01', '2021-01-17', '2021-02-02', '2021-02-18', '2021-03-06', '2021-03-22', '2021-04-07', '2021-04-23', '2021-05-09', '2021-05-25', '2021-06-10', '2021-06-26', '2021-07-12', '2021-07-28', '2021-08-13', '2021-08-29', '2021-09-14', '2021-09-30', '2021-10-16', '2021-11-01', '2021-11-17', '2021-12-03', '2021-12-19', '2022-01-01', '2022-01-17', '2022-02-02', '2022-02-18', '2022-03-06', '2022-03-22', '2022-04-07', '2022-04-23', '2022-05-09', '2022-05-25', '2022-06-10', '2022-06-26', '2022-07-12', '2022-07-28', '2022-08-13', '2022-08-29', '2022-09-14', '2022-09-30', '2022-10-16', '2022-11-01', '2022-11-17', '2022-12-03', '2022-12-19']
#
#  NDVI mean: [-0.06423856, 0.39516039, 0.78797861, 0.74342326, 0.42358789, 0.82951195, 0.56297014, 0.69106336, 0.27528993, 0.7498113, 0.87237006, 0.86368015, 0.85892503, 0.81836448, 0.86691586, 0.78725508, 0.72426848, 0.83746302, 0.35858878, 0.49154542, 0.16417743, 0.73711392, 0.78162384, 0.08747906, 0.77335974, 0.63169461, 0.8161483, 0.45781856, 0.3699042, 0.71535521, 0.67234052, 0.79867665, 0.87583875, 0.74734863, 0.85290132, 0.85187504, 0.82554896, 0.86876236, 0.80951854, 0.84416231, 0.78809569, 0.84207325, 0.76081325, 0.72350782, 0.49847462, 0.40025314, 0.02423104, 0.65011493, 0.12697661, 0.70078256, 0.80253637, 0.03393692, 0.72210487, 0.02025119, 0.7675075, 0.82108141, 0.77522897, 0.85303968, 0.86271117, 0.76353974, 0.70881821, 0.8841142, 0.84087108, 0.85029087, 0.51720242, 0.70207608, -0.04549016, 0.78081583, 0.21771895]

# %% [markdown]
# ### 4.2) The value of each aggregation on each datetime for each attribute is available in a pandas dataframe format

# %%
aggregation_df = summarize.df()
aggregation_df
# Out:
#     attribute aggregation   datetime     value
# 0        NDVI         min 2020-01-01 -0.098300
# 1        NDVI         max 2020-01-01 -0.043700
# 2        NDVI        mean 2020-01-01 -0.064239
# 3        NDVI      median 2020-01-01 -0.064400
# 4        NDVI         std 2020-01-01  0.005884
# ..        ...         ...        ...       ...
# 340      NDVI         min 2022-12-19  0.109000
# 341      NDVI         max 2022-12-19  0.467300
# 342      NDVI        mean 2022-12-19  0.217719
# 343      NDVI      median 2022-12-19  0.208700
# 344      NDVI         std 2022-12-19  0.046690
#
# [345 rows x 4 columns]

# %% [markdown]
# ### 4.3) The user can plot the summarized timeseries

# %%
# Plot the selected aggregation chart for the selected attribute(s)
summarize.plot(
    attributes = ['NDVI'],
    aggregation = 'mean'
)
