# %% [markdown]
# <img src="../../../img/logo-bdc.png" align="right" width="64" />
#
# # <span style="color:#336699">NDVI calculation on images obtained through STAC</span>
# <hr style="border:2px solid #0077b9;">
#
# <div style="text-align: left;">
#     <a href="https://nbviewer.jupyter.org/github/brazil-data-cube/code-gallery/blob/master/jupyter/Python/stac/stac-ndvi-calculation.ipynb"><img src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg" align="center"/></a>
# </div>
#
# <br/>
#
# <div style="text-align: center;font-size: 90%;">
#     Rennan Marujo<sup><a href="https://orcid.org/0000-0002-0082-9498"><i class="fab fa-lg fa-orcid" style="color: #a6ce39"></i></a></sup>, Gilberto R. Queiroz<sup><a href="https://orcid.org/0000-0001-7534-0219"><i class="fab fa-lg fa-orcid" style="color: #a6ce39"></i></a></sup>
#     <br/><br/>
#     Earth Observation and Geoinformatics Division, National Institute for Space Research (INPE)
#     <br/>
#     Avenida dos Astronautas, 1758, Jardim da Granja, São José dos Campos, SP 12227-010, Brazil
#     <br/><br/>
#     Contact: <a href="mailto:brazildatacube@inpe.br">brazildatacube@inpe.br</a>
#     <br/><br/>
#     Last Update: March 22, 2021
# </div>
#
# <br/>
#
# <div style="text-align: justify;  margin-left: 25%; margin-right: 25%;">
# <b>Abstract.</b> This Jupyter Notebook describes how to search for CBERS-4 data products in <em>Brazil Data Cube</em>'s catalog through the STAC service, and how to compute the Normalized Difference Vegetation Index (NDVI) based on the red and near-infrared spectral bands.
# </div>
#
# <br/>
# <div style="text-align: justify;  margin-left: 25%; margin-right: 25%;font-size: 75%; border-style: solid; border-color: #0077b9; border-width: 1px; padding: 5px;">
#     <b>For an introduction to the SpatioTemporal Asset Catalog (STAC) with the <em>Brazil Data Cube</em> infrastructure, please, refer to the following Jupyter Notebook:</b>
#     <div style="margin-left: 10px; margin-right: 10px">
#     Zaglia, M.; Marujo, R.; Queiroz, G. R. <a href="./stac-introduction.ipynb" target="_blank">Introduction to the SpatioTemporal Asset Catalog (STAC)</a>.
#     </div>
# </div>

# %% [markdown]
# # STAC Client API
# <hr style="border:1px solid #0077b9;">
#
# For running the examples in this Jupyter Notebook you will need to install the [STAC client for Python](https://github.com/brazil-data-cube/stac.py). To install it from PyPI using `pip`, use the following command:

# %%
# !pip install stac.py

# %% [markdown]
# In order to access the funcionalities of the client API, you should import the `stac` package, as follows:

# %%
import stac

# %% [markdown]
# After that, you can check the installed `stac` package version:

# %%
stac.__version__

# %% [markdown]
# Then, create a `STAC` object attached to the Brazil Data Cube' STAC service:

# %%
service = stac.STAC('https://brazildatacube.dpi.inpe.br/stac/', access_token='change-me')

# %% [markdown]
# # Searching for CBERS-4 Images
# <hr style="border:1px solid #0077b9;">

# %% [markdown]
# We are going to use the STAC `search` API to look for images from the data cube named `CB4_64_16D_STK`. This data cube is a temporal composite from CBERS-4/AWFI surface reflectance data. Let's define a search box with the following bounds: $x_{min} = -54.0$, $x_{max} = -53.0$, $y_{min} = -24.0$, $y_{max} = -23.0$. Besides that, the period of interest ranges from August 1st, 2018 to July 31st, 2019.

# %%
items = service.search({
    'collections': ['CB4_64_16D_STK-1'], 
    'bbox': '-54.0,-24.0,-53.0,-23.0',
    'datetime': '2018-08-01/2019-07-31', 
    'limit': 30
})

# %%
items

# %% [markdown]
# The above query, should return 24 items for this particular data cube:

# %%
len(items.features)

# %% [markdown]
# # Calculating the Normalized Difference Vegetation Index (NDVI)
# <hr style="border:1px solid #0077b9;">

# %% [markdown]
# The normalized difference vegetation index (NDVI) is calculated using the **Red** and **Near Infrared** (NIR) spectral bands. It assesses whether or not the target being observed contains live green vegetation. It can be calculated through the following equation:
#
# $$
# NDVI = \frac{(NIR - RED)}{(NIR + RED)}
# $$
#
# <center><b>Equation 1</b> - NDVI.</center>

# %% [markdown]
# We are going to compute the NDVI just with images from the first item:

# %%
item = items.features[0]

# %% [markdown]
# In order to know which band is available in an item, one can access its metadata:

# %%
item
# Out:
# {'type': 'Feature',
#  'id': 'CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12',
#  'collection': 'CB4_64_16D_STK-1',
#  'stac_version': '0.9.0',
#  'stac_extensions': ['checksum', 'commons', 'eo'],
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-47.735397, -26.882327],
#     [-47.83099, -22.873503],
#     [-54.363335, -22.936682],
#     [-54.368967, -26.947548],
#     [-47.735397, -26.882327]]]},
#  'bbox': [-54.368967, -26.947548, -47.735397, -22.873503],
#  'properties': {'bdc:tiles': ['021027'],
#   'datetime': '2019-07-28T00:00:00',
#   'start_datetime': '2019-07-28T00:00:00',
#   'end_datetime': '2019-08-12T00:00:00',
#   'created': '2020-09-09T12:53:57',
#   'updated': '2020-09-09T12:53:57',
#   'eo:gsd': 64.0,
#   'eo:bands': [{'name': 'BAND13',
#     'common_name': 'blue',
#     'description': '',
#     'min': 0.0,
#     'max': 10000.0,
#     'nodata': -9999.0,
#     'scale': 0.0001,
#     'center_wavelength': 0.485,
#     'full_width_half_max': 0.07,
#     'data_type': 'int16'},
#    {'name': 'BAND14',
#     'common_name': 'green',
#     'description': '',
#     'min': 0.0,
#     'max': 10000.0,
#     'nodata': -9999.0,
#     'scale': 0.0001,
#     'center_wavelength': 0.555,
#     'full_width_half_max': 0.07,
#     'data_type': 'int16'},
#    {'name': 'BAND15',
#     'common_name': 'red',
#     'description': '',
#     'min': 0.0,
#     'max': 10000.0,
#     'nodata': -9999.0,
#     'scale': 0.0001,
#     'center_wavelength': 0.66,
#     'full_width_half_max': 0.06,
#     'data_type': 'int16'},
#    {'name': 'BAND16',
#     'common_name': 'nir',
#     'description': '',
#     'min': 0.0,
#     'max': 10000.0,
#     'nodata': -9999.0,
#     'scale': 0.0001,
#     'center_wavelength': 0.83,
#     'full_width_half_max': 0.12,
#     'data_type': 'int16'},
#    {'name': 'EVI',
#     'common_name': 'evi',
#     'description': 'Enhanced Vegetation Index',
#     'min': -10000.0,
#     'max': 10000.0,
#     'nodata': -9999.0,
#     'scale': 0.0001,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'int16'},
#    {'name': 'NDVI',
#     'common_name': 'ndvi',
#     'description': '',
#     'min': -10000.0,
#     'max': 10000.0,
#     'nodata': -9999.0,
#     'scale': 0.0001,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'int16'},
#    {'name': 'CLEAROB',
#     'common_name': 'ClearOb',
#     'description': 'Clear Observation Count',
#     'min': 1.0,
#     'max': 255.0,
#     'nodata': 0.0,
#     'scale': 1.0,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'uint8'},
#    {'name': 'CMASK',
#     'common_name': 'quality',
#     'description': '',
#     'min': 0.0,
#     'max': 4.0,
#     'nodata': 255.0,
#     'scale': 1.0,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'uint8'},
#    {'name': 'PROVENANCE',
#     'common_name': 'Provenance',
#     'description': 'Provenance value Day of Year',
#     'min': 1.0,
#     'max': 366.0,
#     'nodata': -1.0,
#     'scale': 1.0,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'uint8'},
#    {'name': 'TOTALOB',
#     'common_name': 'TotalOb',
#     'description': 'Total Observation Count',
#     'min': 1.0,
#     'max': 255.0,
#     'nodata': 0.0,
#     'scale': 1.0,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'uint8'}],
#   'eo:cloud_cover': 2.41,
#   'instruments': ['AWFI'],
#   'platform': 'CBERS-4',
#   'bdc:metadata': {'sources': [{'name': 'CBERS-4 (AWFI) - Cube Identity - v001',
#      'stacUri': 'http://brazildatacube.dpi.inpe.br/stac/collections/CB4_64-1',
#      'descriptionUri': 'https://brazil-data-cube.github.io/products/cube_col/CB4_64.html'}],
#    'datacite': {'id': 'CB4_64_16D_STK',
#     'dates': [{'date': '2020'}],
#     'sizes': [],
#     'state': 'unfindable',
#     'types': {'ris': 'DATA',
#      'bibtex': 'misc',
#      'citeproc': 'dataset',
#      'schemaOrg': 'Dataset',
#      'resourceType': 'Dataset',
#      'resourceTypeGeneral': 'Dataset'},
#     'agency': 'INPE',
#     'titles': {'lang': 'en',
#      'title': 'CBERS-4 AWFI Data Cube Product, 16 days, 64 meters, stack'},
#     'formats': [],
#     'version': '4.',
#     'creators': [{'@type': 'ResearchGroup', 'familyName': 'BDC Team'}],
#     'language': 'en',
#     'subjects': [{'lang': 'en', 'subject': 'CBERS'},
#      {'lang': 'en', 'subject': 'AWFI'},
#      {'lang': 'en', 'subject': 'Bottom Of Atmosphere Reflectance'},
#      {'lang': 'en', 'subject': 'Surface Reflectance'},
#      {'lang': 'en', 'subject': 'Data Cube'},
#      {'lang': 'en', 'subject': 'Brazil'}],
#     'rightsList': [{'rights': 'Terms and Conditions for the use and distribution of CBERS Data',
#       'rightsUri': 'http://mtc-m16c.sid.inpe.br/col/dpi.inpe.br/banon/2006/08.03.19.25/doc/appl_07_2004.pdf'}],
#     'contributors': [{'name': 'National Institute for Space Research (INPE)',
#       'nameType': 'Organizational',
#       'contributorType': 'HostingInstitution'},
#      {'name': 'BDC Team', 'contributorType': 'ResearchGroup'}],
#     'descriptions': [{'lang': 'en',
#       'description': "This datacube was generated with all available images surface reflectance images from CBERS-4/AWFI with 64 meters of spatial resolution, reprojected and cropped to BDC_LG grid, considering a temporal compositing function of 16 days using the best pixel approach (Stack). According to the INPE's web site, CBERS is a cooperative program of China and Brazil containing 4 sensors (MUX, PAN, IRS and AWFI). The AWFI camera contains four spectral bands (blue, green, red and NIR), with a swath of 866km and a revisit period of 5 days. For more information on CBERS-4, please, see http://www.cbers.inpe.br/sobre/cbers3-4.php. This dataset was processed and made available by the Brazil Data Cube project, a component of the Environmental Monitoring of Brazilian Biomes project, funded by the Amazon Fund through the financial collaboration of the Brazilian Development Bank (BNDES) and the Foundation for Science, Technology and Space Applications (FUNCATE) no. 17.2.0536.1.",
#       'descriptionType': 'Abstract'}],
#     'geoLocations': [],
#     'schemaVersion': 'http://datacite.org/schema/kernel-4',
#     'fundingReferences': [{'funderName': 'Brazilian Development Bank (BNDES)'}],
#     'relatedIdentifiers': [{'title': 'Earth Observation Data Cubes for Brazil: Requirements, Methodology and Products',
#       'relationType': 'IsDescribedBy',
#       'relatedIdentifier': '10.3390/rs12244033',
#       'relatedIdentifierType': 'DOI'},
#      {'title': 'Using Remote Sensing Images and Cloud Services on AWS to Improve Land Use and Cover Monitoring',
#       'relationType': 'IsCitedBy',
#       'relatedIdentifier': '10.1109/LAGIRS48042.2020.9165649',
#       'relatedIdentifierType': 'DOI'}]},
#    'processor': {'uri': 'https://github.com/brazil-data-cube/cube-builder',
#     'name': 'Cube Builder',
#     'version': '0.4.0'}}},
#  'assets': {'EVI': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/CB4_64_16D_STK/v001/021027/2019-07-28_2019-08-12/CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12_EVI.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'created': '2020-09-14T19:08:35',
#    'updated': '2020-09-14T19:08:35',
#    'bdc:size': 215985661,
#    'bdc:chunk_size': {'x': 256, 'y': 256},
#    'bdc:raster_size': {'x': 10504, 'y': 6865},
#    'checksum:multihash': '12209b710b5f968318422fbb52d69c3404eb0affba6579dc36b6f37ca3571630562f',
#    'eo:bands': [4]},
#   'NDVI': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/CB4_64_16D_STK/v001/021027/2019-07-28_2019-08-12/CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12_NDVI.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'created': '2020-09-14T19:08:36',
#    'updated': '2020-09-14T19:08:36',
#    'bdc:size': 217711685,
#    'bdc:chunk_size': {'x': 256, 'y': 256},
#    'bdc:raster_size': {'x': 10504, 'y': 6865},
#    'checksum:multihash': '122037fface4cfa7f549f97469792e8b5245b54844a6e581c67b1fff261daf4fe9e4',
#    'eo:bands': [5]},
#   'CMASK': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/CB4_64_16D_STK/v001/021027/2019-07-28_2019-08-12/CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12_CMASK.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'created': '2020-09-14T19:08:37',
#    'updated': '2020-09-14T19:08:37',
#    'bdc:size': 1098927,
#    'bdc:chunk_size': {'x': 256, 'y': 256},
#    'bdc:raster_size': {'x': 10504, 'y': 6865},
#    'checksum:multihash': '12201513bbed5854ecf86de72658137a252f8b5f17f3830503ffed0590b8d6b95791',
#    'eo:bands': [7]},
#   'BAND13': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/CB4_64_16D_STK/v001/021027/2019-07-28_2019-08-12/CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12_BAND13.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'created': '2020-09-14T19:08:38',
#    'updated': '2020-09-14T19:08:38',
#    'bdc:size': 153365225,
#    'bdc:chunk_size': {'x': 256, 'y': 256},
#    'bdc:raster_size': {'x': 10504, 'y': 6865},
#    'checksum:multihash': '12203a04ee89db6d180ee12151ab8118c0bee39652c4a6620a309793786d1c9af01d',
#    'eo:bands': [0]},
#   'BAND14': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/CB4_64_16D_STK/v001/021027/2019-07-28_2019-08-12/CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12_BAND14.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'created': '2020-09-14T19:08:39',
#    'updated': '2020-09-14T19:08:39',
#    'bdc:size': 160939269,
#    'bdc:chunk_size': {'x': 256, 'y': 256},
#    'bdc:raster_size': {'x': 10504, 'y': 6865},
#    'checksum:multihash': '12205e95aebad0b312cf310d92d229676580b71d45ae68891c5ff4571ce3a6b065c4',
#    'eo:bands': [1]},
#   'BAND15': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/CB4_64_16D_STK/v001/021027/2019-07-28_2019-08-12/CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12_BAND15.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'created': '2020-09-14T19:08:40',
#    'updated': '2020-09-14T19:08:40',
#    'bdc:size': 167606801,
#    'bdc:chunk_size': {'x': 256, 'y': 256},
#    'bdc:raster_size': {'x': 10504, 'y': 6865},
#    'checksum:multihash': '1220aeb1fdcf075cb00acf6d01bf5b23f711f76d6c154cc1f354b6bdf7a4d49aae76',
#    'eo:bands': [2]},
#   'BAND16': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/CB4_64_16D_STK/v001/021027/2019-07-28_2019-08-12/CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12_BAND16.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'created': '2020-09-14T19:08:41',
#    'updated': '2020-09-14T19:08:41',
#    'bdc:size': 194943471,
#    'bdc:chunk_size': {'x': 256, 'y': 256},
#    'bdc:raster_size': {'x': 10504, 'y': 6865},
#    'checksum:multihash': '1220faedc012f1c23fcad1776747d395401f29cb9c14702fd7ce04753940110ab5bd',
#    'eo:bands': [3]},
#   'CLEAROB': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/CB4_64_16D_STK/v001/021027/2019-07-28_2019-08-12/CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12_CLEAROB.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'created': '2020-09-14T19:08:42',
#    'updated': '2020-09-14T19:08:42',
#    'bdc:size': 5391813,
#    'bdc:chunk_size': {'x': 256, 'y': 256},
#    'bdc:raster_size': {'x': 10504, 'y': 6865},
#    'checksum:multihash': '1220b2ca4e29efc4d39031d6a1b5f72883778f7a280e282f7ba7e1236b858f8abcb2',
#    'eo:bands': [6]},
#   'TOTALOB': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/CB4_64_16D_STK/v001/021027/2019-07-28_2019-08-12/CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12_TOTALOB.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'created': '2020-09-14T19:08:42',
#    'updated': '2020-09-14T19:08:42',
#    'bdc:size': 1106341,
#    'bdc:chunk_size': {'x': 256, 'y': 256},
#    'bdc:raster_size': {'x': 10504, 'y': 6865},
#    'checksum:multihash': '12204f9b8acfa5941dd57ce5fb68701533951fc2fdcdb6c400f9be93860e409247d1',
#    'eo:bands': [9]},
#   'thumbnail': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/CB4_64_16D_STK/v001/021027/2019-07-28_2019-08-12/CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12.png',
#    'type': 'image/png',
#    'roles': ['thumbnail'],
#    'created': '2020-09-14T19:08:42',
#    'updated': '2020-09-14T19:08:42',
#    'bdc:size': 1859828,
#    'checksum:multihash': '1220cd4dcd912bc5f30451c0fe1a937de61c18850d927f54e8fa79c8bd58b1e84b1c'},
#   'PROVENANCE': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/CB4_64_16D_STK/v001/021027/2019-07-28_2019-08-12/CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12_PROVENANCE.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'created': '2020-09-14T19:08:42',
#    'updated': '2020-09-14T19:08:42',
#    'bdc:size': 3100355,
#    'bdc:chunk_size': {'x': 256, 'y': 256},
#    'bdc:raster_size': {'x': 10504, 'y': 6865},
#    'checksum:multihash': '1220c3bdf802f6514261f001cbb46c6cd094cfee76749cf07b052d554deecccd440f',
#    'eo:bands': [8]}},
#  'links': [{'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/CB4_64_16D_STK-1/items/CB4_64_16D_STK_v001_021027_2019-07-28_2019-08-12',
#    'rel': 'self'},
#   {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/CB4_64_16D_STK-1',
#    'rel': 'parent'},
#   {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/CB4_64_16D_STK-1',
#    'rel': 'collection'},
#   {'href': 'https://brazildatacube.dpi.inpe.br/stac/', 'rel': 'root'}]}

# %% [markdown]
# <div style="text-align: center;  margin-left: 15%; margin-right: 15%; border-style: solid; border-color: #0077b9; border-width: 1px; padding: 5px;">
#     <b>Note:</b> As one can see, in the above metadata the Brazil Data Cube already provides the <em>NDVI</em> and <em>EVI</em> alongside with the spectral bands for the data cubes, besides the quality indicators (<em>CLEAROB</em>, <em>PROVENANCE</em>, <em>CMASK</em>, <em>TOTALOB</em>).
# </div>

# %% [markdown]
# As one can see in the above cell, the `BAND15` correspond to the red wavelength and `BAND16` to the near-infrared.
#
# The `read` method from an `item` allows to read the image from the service besides creating a NumPy array. We are going to retrieve a subset of the images corresponing to the bands, with 500 x 500 pixels:

# %%
from rasterio.windows import Window

# %%
red = item.read('BAND15', window=Window(0, 0, 500, 500))

# %%
nir = item.read('BAND16', window=Window(0, 0, 500, 500))

# %% [markdown]
# Let's take a look at the retrieved data:

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(red, cmap='gray')

# %%
plt.imshow(nir, cmap='gray')

# %% [markdown]
# Finally, let's compute the NDVI:

# %%
ndvi = (nir - red)/(nir + red)
ndvi

# %% [markdown]
# Use the Matplotlib to visualize the result array:

# %%
plt.imshow(ndvi, cmap='gray')
